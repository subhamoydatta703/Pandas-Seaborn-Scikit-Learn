# %%
import numpy as np
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
)

# %% [markdown]
# ### Data cleaning

# %%
data = {
    "Age": [25, 35, 45, 55, 65, 28, 38, 48, 58, 68],
    "BP": [120, 130, 145, 160, 175, 118, 135, 150, 165, 180],
    "Cholesterol": [180, 200, 220, 250, 280, 175, 205, 230, 260, 290],
    "Disease": ["No", "No", "Yes", "Yes", "Yes",
                "No", "No", "Yes", "Yes", "Yes"]
}

df = pd.DataFrame(data)

# %%
print(df)
# Out:
#    Age   BP  Cholesterol Disease
# 0   25  120          180      No
# 1   35  130          200      No
# 2   45  145          220     Yes
# 3   55  160          250     Yes
# 4   65  175          280     Yes
# 5   28  118          175      No
# 6   38  135          205      No
# 7   48  150          230     Yes
# 8   58  165          260     Yes
# 9   68  180          290     Yes

# %%
x = df[["Age", "BP", "Cholesterol"]]
y = df["Disease"]

# %% [markdown]
# ### Model training and prediction

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.33, random_state=42
)

model = LogisticRegression()
model.fit(x_train, y_train)
predictions = model.predict(x_test)

for actual, predicted in zip(y_test, predictions):
    if actual == predicted:
        result = "Correct prediction"
    else:
        result = "Wrong prediction"

    print(
        f"Actual: {actual} | Predicted: {predicted} | Result: {result}"
    )
# Out:
# Actual: Yes | Predicted: Yes | Result: Correct prediction
# Actual: No | Predicted: No | Result: Correct prediction
# Actual: No | Predicted: No | Result: Correct prediction
# Actual: No | Predicted: No | Result: Correct prediction

# %% [markdown]
# ### Checking model accuracy, precision and recall it

# %%
accuracy = accuracy_score(y_test, predictions)

precision = precision_score(y_test, predictions, pos_label="Yes")

recall = recall_score(
    y_test,
    predictions,
    pos_label="Yes"
)

f1 = f1_score(
    y_test,
    predictions,
    pos_label="Yes"
)

print(accuracy)
# Out:
# 1.0

# %%
actual_disease = y_test.tolist().count("Yes")

found_disease = 0

for actual, predicted in zip(y_test, predictions):
    if actual == "Yes" and predicted == "Yes":
        found_disease += 1

print(f"Actual diseses: {actual_disease}")
print(f"Found(predicted) diseases: {found_disease}")
# Out:
# Actual diseses: 1
# Found(predicted) diseases: 1

# %% [markdown]
# ### Predict disease for new patient data

# %%
new_patient = pd.DataFrame({
    "Age": [52],
    "BP": [155],
    "Cholesterol": [245]
})
prediction = model.predict(new_patient)
print(prediction)
# Out:
# ['Yes']
